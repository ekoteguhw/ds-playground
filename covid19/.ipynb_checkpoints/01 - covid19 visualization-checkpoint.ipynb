# %% [markdown]
# ## Import Package

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data from Resource
#
# Data repository by John Hopkins CSSE.
# https://github.com/CSSEGISandData/COVID-19

# %%
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
country_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')

# %%
death_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  \
# 0        0        0        0  ...      11      14      14      15       15
# 1        0        0        0  ...      21      22      22      23       23
# 2        0        0        0  ...     173     193     205     235      256
# 3        0        0        0  ...      21      22      23      25       26
# 4        0        0        0  ...       2       2       2       2        2
#
#    4/11/20  4/12/20  4/13/20  4/14/20  4/15/20
# 0       18       18       21       23       25
# 1       23       23       23       24       25
# 2      275      293      313      326      336
# 3       26       29       29       31       33
# 4        2        2        2        2        2
#
# [5 rows x 89 columns]

# %%
confirmed_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  \
# 0        0        0        0  ...     367     423     444     484      521
# 1        0        0        0  ...     377     383     400     409      416
# 2        0        0        0  ...    1423    1468    1572    1666     1761
# 3        0        0        0  ...     525     545     564     583      601
# 4        0        0        0  ...      16      17      19      19       19
#
#    4/11/20  4/12/20  4/13/20  4/14/20  4/15/20
# 0      555      607      665      714      784
# 1      433      446      467      475      494
# 2     1825     1914     1983     2070     2160
# 3      601      638      646      659      673
# 4       19       19       19       19       19
#
# [5 rows x 89 columns]

# %%
recovered_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  \
# 0        0        0        0  ...      18      18      29      32       32
# 1        0        0        0  ...     116     131     154     165      182
# 2        0        0        0  ...      90     113     237     347      405
# 3        0        0        0  ...      31      39      52      58       71
# 4        0        0        0  ...       2       2       2       2        2
#
#    4/11/20  4/12/20  4/13/20  4/14/20  4/15/20
# 0       32       32       32       40       43
# 1      197      217      232      248      251
# 2      460      591      601      691      708
# 3       71      128      128      128      169
# 4        4        4        4        5        5
#
# [5 rows x 89 columns]

# %%
country_df.head()
# Out:
#   Country_Region          Last_Update      Lat     Long_  Confirmed  Deaths  \
# 0      Australia  2020-04-16 18:26:23 -25.0000  133.0000       6462      63
# 1        Austria  2020-04-16 18:18:47  47.5162   14.5501      14474     393
# 2         Canada  2020-04-16 18:26:06  60.0010  -95.0010      30436    1229
# 3          China  2020-04-16 14:09:41  30.5928  114.3055      83403    3346
# 4        Denmark  2020-04-16 18:18:47  56.0000   10.0000       7074     321
#
#    Recovered  Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 0       2355    4044      25.381289            NaN                  NaN
# 1       8986    5095     160.707941            NaN                  NaN
# 2       9671   19536      80.400041            NaN                  NaN
# 3      78401    1656       5.937524            NaN                  NaN
# 4       3203    3550     122.129697            NaN                  NaN
#
#    Mortality_Rate  UID ISO3
# 0        0.974930   36  AUS
# 1        2.715213   40  AUT
# 2        4.037981  124  CAN
# 3        4.011846  156  CHN
# 4        4.537744  208  DNK

# %% [markdown]
# ## Data Cleaning

# %%
# Make the column names become lowercase
country_df.columns = map(str.lower, country_df.columns)
country_df.columns
# Out:
# Index(['country_region', 'last_update', 'lat', 'long_', 'confirmed', 'deaths',
#        'recovered', 'active', 'incident_rate', 'people_tested',
#        'people_hospitalized', 'mortality_rate', 'uid', 'iso3'],
#       dtype='object')

# %%
# Implement similar to other tables
death_df.columns = map(str.lower, death_df.columns)
confirmed_df.columns = map(str.lower, confirmed_df.columns)
recovered_df.columns = map(str.lower, recovered_df.columns)

# %%
# Rename province/state to state and country/region column names to country
confirmed_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
confirmed_df.head()
# Out:
#   state      country      lat     long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0   NaN  Afghanistan  33.0000  65.0000        0        0        0        0
# 1   NaN      Albania  41.1533  20.1683        0        0        0        0
# 2   NaN      Algeria  28.0339   1.6596        0        0        0        0
# 3   NaN      Andorra  42.5063   1.5218        0        0        0        0
# 4   NaN       Angola -11.2027  17.8739        0        0        0        0
#
#    1/26/20  1/27/20  ...  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  \
# 0        0        0  ...     367     423     444     484      521      555
# 1        0        0  ...     377     383     400     409      416      433
# 2        0        0  ...    1423    1468    1572    1666     1761     1825
# 3        0        0  ...     525     545     564     583      601      601
# 4        0        0  ...      16      17      19      19       19       19
#
#    4/12/20  4/13/20  4/14/20  4/15/20
# 0      607      665      714      784
# 1      446      467      475      494
# 2     1914     1983     2070     2160
# 3      638      646      659      673
# 4       19       19       19       19
#
# [5 rows x 89 columns]

# %%
# Implement similar to other tables
death_df = death_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
recovered_df = recovered_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
country_df = country_df.rename(columns={'country_region': 'country'})

# %% [markdown]
# Sorting by `confirmed`, highlighting columns, and calculating total cases

# %%
# Sorting contry_df by confirmed case desc
sorted_country_df = country_df.sort_values('confirmed', ascending=False)
sorted_country_df.head()
# Out:
#      country          last_update        lat      long_  confirmed  deaths  \
# 17        US  2020-04-16 18:19:05  40.000000 -100.00000     648788   30920
# 160    Spain  2020-04-16 18:18:47  40.463667   -3.74922     182816   19130
# 10     Italy  2020-04-16 18:18:47  41.871900   12.56740     168941   22170
# 7    Germany  2020-04-16 18:18:47  51.165700   10.45150     135663    3867
# 6     France  2020-04-16 18:18:47  46.227600    2.21370     134598   17188
#
#      recovered  active  incident_rate  people_tested  people_hospitalized  \
# 17       53489  564379     196.920909            NaN                  NaN
# 160      74797   88889     391.010263            NaN                  NaN
# 10       40164  106607     279.417619            NaN                  NaN
# 7        77000   54796     161.920043            NaN                  NaN
# 6        31470   85940     206.206156            NaN                  NaN
#
#      mortality_rate  uid iso3
# 17         4.765809  840  USA
# 160       10.464073  724  ESP
# 10        13.122925  380  ITA
# 7          2.850446  276  DEU
# 6         12.769878  250  FRA

# %%
def highlight_col(x):
    r = 'background-color: red'
    g = 'background-color: green'
    b = 'background-color: blue'
    temp_df = pd.DataFrame('', index=x.index, columns=x.columns)
    temp_df.iloc[:,4] = r
    temp_df.iloc[:,5] = g
    temp_df.iloc[:,6] = b
    return temp_df

# %%
sorted_country_df.style.apply(highlight_col, axis=None)
# Out:
# <style  type="text/css" >
#     #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow0_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow0_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow0_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow1_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow1_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow1_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow2_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow2_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow2_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow3_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow3_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow3_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow4_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow4_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow4_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow5_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow5_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow5_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow6_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow6_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow6_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow7_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow7_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow7_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow8_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow8_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow8_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow9_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow9_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow9_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow10_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow10_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow10_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow11_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow11_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow11_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow12_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow12_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow12_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow13_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow13_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow13_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow14_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow14_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow14_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow15_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow15_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow15_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow16_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow16_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow16_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow17_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow17_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow17_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow18_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow18_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow18_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow19_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow19_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow19_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow20_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow20_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow20_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow21_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow21_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow21_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow22_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow22_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow22_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow23_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow23_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow23_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow24_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow24_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow24_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow25_col4 {
#             background-color:  red;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow25_col5 {
#             background-color:  green;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow25_col6 {
#             background-color:  blue;
#         }    #T_d84a00e6_8011_11ea_8571_7c04d0c2fd2crow26

# %%
def total_cases(x):
    confirmed_total = int(x['confirmed'].sum())
    deaths_total = int(x['deaths'].sum())
    recovered_total = int(x['recovered'].sum())
    return confirmed_total, deaths_total, recovered_total

# %%
c, d, r = total_cases(sorted_country_df)
print(f'Confirmed Cases: {c}\nDeaths Cases: {d}\nRecovered Cases: {r}')
# Out:
# Confirmed Cases: 2113226
# Deaths Cases: 140371
# Recovered Cases: 537475

# %% [markdown]
# ## Basic Visualization
#
# Using `matplotlib`

# %%
# Diplay bubble chart by country by confirmed and deaths cases

# Top 10 countries
countries = sorted_country_df['country'].head(10)
countries_confirmed = sorted_country_df['confirmed'].head(10)
countries_death = sorted_country_df['deaths'].head(10)

fig = plt.figure(figsize=(16, 8))
ax = fig.add_subplot(111)

colors = np.random.rand(len(countries)) / 100

# Choosing colormap https://matplotlib.org/3.1.1/tutorials/colors/colormaps.html
ax.scatter(countries_death/1000, countries_confirmed, c=colors, s=countries_confirmed/20, alpha=0.7, cmap='viridis')

ax.set_xlabel('Death Rate Per 1000 Population')
ax.set_ylabel('Number of confirmed cases')

offset = 0.5
for x, y, country in zip(countries_death/1000, countries_confirmed, countries):
    ax.text(x - offset, y, country, va='center')

plt.show()

# %%
# Display daily cases of a country
def daily_cases_country(country):
    c_date, c_case, d_date, d_case, r_date, r_case = [], [], [], [], [], []
    
    if country.lower() == 'world':
        c_date = np.array(list(confirmed_df.iloc[:, 4:].columns))
        c_case = np.sum(np.asarray(confirmed_df.iloc[:, 4:]), axis=0)
        d_date = np.array(list(death_df.iloc[:, 4:].columns))
        d_case = np.sum(np.asarray(death_df.iloc[:, 4:]), axis=0)
        r_date = np.array(list(recovered_df.iloc[:, 4:].columns))
        r_case = np.sum(np.asarray(recovered_df.iloc[:, 4:]), axis=0)
    else:
        c_date = np.array(list(confirmed_df.iloc[:, 4:].columns))
        c_case = np.sum(np.asarray(confirmed_df[confirmed_df['country'] == country].iloc[:, 4:]), axis=0)
        d_date = np.array(list(death_df.iloc[:, 4:].columns))
        d_case = np.sum(np.asarray(death_df[death_df['country'] == country].iloc[:, 4:]), axis=0)
        r_date = np.array(list(recovered_df.iloc[:, 4:].columns))
        r_case = np.sum(np.asarray(recovered_df[recovered_df['country'] == country].iloc[:, 4:]), axis=0)

    plt.figure(figsize=(14, 6))
    plt.plot(c_date, c_case)
    plt.plot(d_date, d_case)
    plt.plot(r_date, r_case)
    plt.legend(["Confirmed", "Death", "Recovered"])
    plt.title(f"Day vs Total Cases in {country}")
    plt.xlabel("Day")
    plt.ylabel("Total Case")
    plt.xticks(rotation=90) # Rotate axis to 90 degree
    plt.show()

interact(daily_cases_country, country='World')
# Out:
# interactive(children=(Text(value='World', description='country'), Output()), _dom_classes=('widget-interact',)…
# <function __main__.daily_cases_country(country)>
